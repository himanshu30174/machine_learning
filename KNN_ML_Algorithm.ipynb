# %%
#Python Program to Implement KNN ML Model on IPL Dataset
#Author Name: Himanshu Sharma
#Program Date: 25/05/2021
#Program Time: 01:28AM

#Import the required libraries for algorithm
import pandas as pd
import numpy as np
import math

def eculids_distance(testing_index,training_index):
#This method finds the eculids distance between two instances
#testing_index: testing instance index
#training_index: training instance index
    test_instance = dataset[testing_index]
    train_instance = dataset[training_index]
    overall_difference = 0
    for feature in range (0,max_features):
        current_feature_difference = (test_instance[feature] - train_instance[feature])**2
        overall_difference += current_feature_difference
    return math.sqrt(overall_difference)

def calculate_similarity(i, j, similarity):
#This method creates a dictionary that keeps track of eculids distance wrt every training instance for current testing instance 
#i: testing instance
#j: training instance
#similarity: dictinary for mapping eculid distance with unique ids
    difference = eculids_distance(i,j)
    training_inst_id = dataset[j][instance_id_index]
    similarity[difference] = training_inst_id
    return similarity

def calculate_knn(sorted_similarity, similarity):
#This method fetches top k neighbors based on similarity, then select k nearest
#...neighbours, finds the output class of each neighbour and then returns the class
#...with maximum frequency in the neighbourhood
#sorted_similarity: eculids distance of all training instances wrt current testing instance in sorted order
#similarity: eculids distance of all training instances wrt current testing instance
    #Fetch the top k neighbors from the sorted similarity
    k_neighbours = np.zeros(k)
    for i in range (0, k):
        key = sorted_similarity[i]
        instance_id = similarity[key]
        row = df.loc[df['id'] == instance_id]
        winner = ((row['winner'].values)[0])
        k_neighbours[i] = winner
    
    #Find the most common neighbour
    neighbour_frequency = {}
    for i in range (0, k):
        current_result = k_neighbours[i]
        if current_result in neighbour_frequency.keys():
            current_frequency = neighbour_frequency[current_result]
            updated_frequency = current_frequency+1
            neighbour_frequency[current_result] = updated_frequency
        else:
            neighbour_frequency[current_result] = 1
    result = max(neighbour_frequency, key = neighbour_frequency.get)
    return result

def add_to_overall_accuracy(difference):
#This method adds the difference of expected and acutal output to overall accuracy
    if difference == 0: return 1
    else: return 0

#Read the input dataset and convert it into an numpy array of integers
df = pd.read_csv(r"IPL_DATASET.csv")
dataset = (df.as_matrix()).astype(int)

#Find the number of instances in the incoming dataset
dataset_shape = dataset.shape
no_of_instances = dataset_shape[0]
no_of_attributes = dataset_shape[1]

#Divide the dataseet into testing and training based on 80% and 20% 
training_size = no_of_instances * (0.8)
testing_size = no_of_instances - training_size

#Hyperparameters for the data model
training_index = 0
testing_index = 640
end_index = no_of_instances
increment = 1
max_features = 6
instance_id_index = 7
k = 9
teams = {0:"DRW", 1:"CSK", 2:"DeC", 3:"DCa", 4:"GuL", 5:"PKi", 6:"KoT", 7:"KKR", 8:"MuI", 9:"PuW", 10:"RaR", 11:"RCB", 12:"SRH"}
testing_accuracy = 0
overall_testing_instances = 160

#Fetch the testing instances one by one
for i in range(testing_index, end_index, increment):
    #Current testing instance
    dataset_testing_instance = dataset[i]
    
    #Dictionary to store all eculidian distances wrt current testing instance
    similarity = {}
    
    #Fetch the training instances against which we have to compare testing instance
    for j in range (training_index,testing_index,increment):
        #Find the eculidian distance of current testing instance with current training
        #instance and save it in similarity dictionary for sorting in similar order later
        similarity = calculate_similarity(i, j, similarity)
            
    #Sort the eculids distances in ascending order so that similar items are in beginning
    sorted_similarity = sorted(similarity)
    
    #Fetch the top k similar neighbors and check which neighbouring class has max frequency
    predicted_result = calculate_knn(sorted_similarity, similarity)
    acutal_result = dataset[i][6]
    difference = predicted_result - acutal_result
    print(teams[dataset[i][2]], " **vs** ", teams[dataset[i][3]],"\t   ","Predicted Winner ::", teams[predicted_result], "\tActual Winner ::",teams[acutal_result])
    testing_accuracy += add_to_overall_accuracy(difference) 
 
print("Predicted ", (testing_accuracy/160)*100, "Percent Results Correctly \nUsing KNN for K = ",k," & Features = 6")
# Out:
# RaR  **vs**  MuI 	    Predicted Winner :: RaR 	Actual Winner :: RaR
# DCa  **vs**  PKi 	    Predicted Winner :: DCa 	Actual Winner :: PKi
# MuI  **vs**  SRH 	    Predicted Winner :: MuI 	Actual Winner :: SRH
# RCB  **vs**  CSK 	    Predicted Winner :: CSK 	Actual Winner :: CSK
# SRH  **vs**  PKi 	    Predicted Winner :: SRH 	Actual Winner :: SRH
# DCa  **vs**  KKR 	    Predicted Winner :: DCa 	Actual Winner :: DCa
# CSK  **vs**  MuI 	    Predicted Winner :: KKR 	Actual Winner :: MuI
# RaR  **vs**  SRH 	    Predicted Winner :: RaR 	Actual Winner :: SRH
# RCB  **vs**  KKR 	    Predicted Winner :: RCB 	Actual Winner :: KKR
# CSK  **vs**  DCa 	    Predicted Winner :: CSK 	Actual Winner :: CSK
# RCB  **vs**  MuI 	    Predicted Winner :: MuI 	Actual Winner :: RCB
# DCa  **vs**  RaR 	    Predicted Winner :: DCa 	Actual Winner :: DCa
# KKR  **vs**  CSK 	    Predicted Winner :: KKR 	Actual Winner :: KKR
# PKi  **vs**  MuI 	    Predicted Winner :: PKi 	Actual Winner :: MuI
# CSK  **vs**  RCB 	    Predicted Winner :: CSK 	Actual Winner :: CSK
# SRH  **vs**  DCa 	    Predicted Winner :: SRH 	Actual Winner :: SRH
# MuI  **vs**  KKR 	    Predicted Winner :: MuI 	Actual Winner :: MuI
# PKi  **vs**  RaR 	    Predicted Winner :: PKi 	Actual Winner :: PKi
# SRH  **vs**  RCB 	    Predicted Winner :: SRH 	Actual Winner :: SRH
# RaR  **vs**  PKi 	    Predicted Winner :: RaR 	Actual Winner :: RaR
# KKR  **vs**  MuI 	    Predicted Winner :: MuI 	Actual Winner :: MuI
# DCa  **vs**  SRH 	    Predicted Winner :: DCa 	Actual Winner :: SRH
# RaR  **vs**  CSK 	    Predicted Winner :: RaR 	Actual Winner :: RaR
# PKi  **vs**  KKR 	    Predicted Winner :: PKi 	Actual Winner :: KKR
# DCa  **vs**  RCB 	    Predicted Winner :: DCa 	Actual Winner :: RCB
# CSK  **vs**  SRH 	    Predicted Winner :: CSK 	Actual Winner :: CSK
# MuI  **vs**  RaR 	    Predicted Winner :: MuI 	Actual Winner :: RaR
# PKi  **vs**  RCB 	    Predicted Winner :: PKi 	Actual Winner :: RCB
# KKR  **vs**  RaR 	    Predicted Winner :: KKR 	Actual Winner :: KKR
# MuI  **vs**  PKi 	    Predicted Winner :: MuI 	Actual Winner :: MuI
# RCB  **vs**  SRH 	    Predicted Winner :: RaR 	Actual Winner :: RCB
# DCa  **vs**  CSK 	    Predicted Winner :: CSK 	Actual Winner :: DCa
# RaR  **vs**  RCB 	    Predicted Winner :: RaR 	Actual Winner :: RaR
# SRH  **vs**  KKR 	    Predicted Winner :: SRH 	Actual Winner :: KKR
# DCa  **vs**  MuI 	    Predicted Winner :: DCa 	Actual Winner :: DCa
# CSK  **vs**  PKi 	    Predicted Winner :: CSK 	Actual Winner :: CSK
# SRH  **vs**  CSK 	    Predicted Winner :: DeC 	Actual Winner :: CSK
# KKR  **vs**  RaR 	    Predicted Winner :: KKR 	Actual Winner :: KKR
# KKR  **vs**  SRH 	    Predicted Winner :: KKR 	Actual Winner :: SRH
# CSK  **vs**  SRH 	    Predicted Winner :: CSK 	Actual Winner :: CSK
# CSK  **vs**  RCB 	    Predicted Winner :: CSK 	Actual Winner :: CSK
# KKR  **vs**  SRH 	    Predicted Winner :: KKR 	Actual Winner :: KKR
# MuI  **vs**  DCa 	    Predicted Winner :: MuI 	Actual Winner :: DCa
# RaR  **vs**  PKi 	    Predicted Winner :: RaR 	Actual Winner :: PKi
# DCa  **vs**  CSK 	    Predicted Winner :: DCa 	Actual Winner :: CSK
# KKR  **vs**  PKi 	    Predicted Winner :: KKR 	Actual Winner :: KKR
# RCB  **vs**  MuI 	    Predicted Winner :: RCB 	Actual Winner :: MuI
# SRH  **vs**  RaR 	    Predicted Winner :: SRH 	Actual Winner :: SRH
# PKi  **vs**  MuI 	    Predicted Winner :: PKi 	Actual Winner :: PKi
# DCa  **vs**  KKR 	    Predicted Winner :: DCa 	Actual Winner :: DCa
# SRH  **vs**  RCB 	    Predicted Winner :: SRH 	Actual Winner :: SRH
# CSK  **vs**  RaR 	    Predicted Winner :: CSK 	Actual Winner :: CSK
# PKi  **vs**  DCa 	    Predicted Winner :: PKi 	Actual Winner :: PKi
# RaR  **vs**  RCB 	    Predicted Winner :: RaR 	Actual Winner :: RaR
# MuI  **vs**  CSK 	    Predicted Winner :: MuI 	Actual Winner :: MuI
# DCa  **vs**  SRH 	    Predicted Winner :: DCa 	Actual Winner :: SRH
# RCB  **vs**  KKR 	    Predicted Winner :: RCB 	Actual Winner :: KKR
# CSK  **vs**  PKi 	    Predicted Winner :: CSK 	Actual Winner :: CSK
# SRH  **vs**  MuI 	    Predicted Winner :: SRH 	Actual Winner :: MuI
# RCB  **vs**  DCa 	    Predicted Winner :: RCB 	Actual Winner :: DCa
# RaR  **vs**  KKR 	    Predicted Winner :: RaR 	Actual Winner :: KKR
# PKi  **vs**  SRH 	    Predicted Winner :: PKi 	Actual Winner :: PKi
# CSK  **vs**  KKR 	    Predicted Winner :: CSK 	Actual Winner :: CSK
# MuI  **vs**  PKi 	    Predicted Winner :: MuI 	Actual Winner :: MuI
# RaR  **vs**  CSK 	    Predicted Winner :: RaR 	Actual Winner :: CSK
# KKR  **vs**  DCa 	    Predicted Winner :: KKR 	Actual Winner :: DCa
# MuI  **vs**  RaR 	    Predicted Winner :: MuI 	Actual Winner :: RaR
# PKi  **vs**  RCB 	    Predicted Winner :: PKi 	Actual Winner :: RCB
# KKR  **vs**  CSK 	    Predicted Winner :: KKR 	Actual Winner :: CSK
# SRH  **vs**  DCa 	    Predicted Winner :: SRH 	Actual Winner :: DCa
# MuI  **vs**  RCB 	    Predicted Winner :: MuI 	Actual Winner :: MuI
# PKi  **vs**  RaR 	    Predicted Winner :: PKi 	Actual Winner :: PKi
# SRH  **vs**  CSK 	    Predicted Winner :: SRH 	Actual Winner :: SRH
# DCa  **vs**  MuI 	    Predicted Winner :: RCB 	Actual Winner :: MuI
# KKR  **vs**  RCB 	    Predicted Winner :: KKR 	Actual Winner :: RCB
# RaR  **vs**  MuI 	    Predicted Winner :: RaR 	Actual Winner :: RaR
# DCa  **vs**  PKi 	    Predicted Winner :: DCa 	Actual Winner :: DCa
# SRH  **vs**  KKR 	    Predicted Winner :: SRH 	Actual Winner :: SRH
# RCB  **vs**  CSK 	    Predicted Winner :: CSK 	Actual Winner :: RCB
# RaR  **vs**  DCa 	    Predicted Winner :: RaR 	Actual Winner :: DCa
# CSK  **vs**  SRH 	    Predicted Winner :: CSK 	Actual Winner :: CSK
# RCB  **vs**  PKi 	    Predicted Winner :: RCB 	Actual Winner :: RCB
# KKR  **vs**  RaR 	    Predicted Winner :: KKR 	Actual Winner :: RaR
# CSK  **vs**  MuI 	    Predicted Winner :: CSK 	Actual Winner :: MuI
# RaR  **vs**  SRH 	    Predicted Winner :: RaR 	Actual Winner :: RaR
# DCa  **vs**  RCB 	    Predicted Winner :: DCa 	Actual Winner :: DCa
# KKR  **vs**  MuI 	    Predicted Winner :: KKR 	Actual Winner :: KKR
# SRH  **vs**  PKi 	    Predicted Winner :: SRH 	Actual Winner :: SRH
# RCB  **vs**  RaR 	    Predicted Winner :: MuI 	Actual Winner :: DRW
# CSK  **vs**  DCa 	    Predicted Winner :: CSK 	Actual Winner :: CSK
# MuI  **vs**  SRH 	    Predicted Winner :: MuI 	Actual Winner :: MuI
# PKi  **vs**  KKR 	    Predicted Winner :: MuI 	Actual Winner :: KKR
# DCa  **vs**  RaR 	    Predicted Winner :: DCa 	Actual Winner :: DCa
# RCB  **vs**  SRH 	    Predicted Winner :: RCB 	Actual Winner :: RCB
# PKi  **vs**  CSK 	    Predicted Winner :: PKi 	Actual Winner :: PKi
# MuI  **vs**  KKR 	    Predicted Winner :: MuI 	Actual Winner :: MuI
# MuI  **vs**  CSK 	    Predicted Winner :: CSK 	Actual Winner :: MuI
# DCa  **vs**  SRH 	    Predicted Winner :: CSK 	Actual Winner :: DCa
# CSK  **vs**  DCa 	    Predicted Winner :: KKR 	Actual Winner :: CSK
# MuI  **vs**  CSK 	    Predicted Winner :: SRH 	Actual Winner :: MuI
# MuI  **vs**  CSK 	    Predicted Winner :: RaR 	Actual Winner :: CSK
# DCa  **vs**  PKi 	    Predicted Winner :: DCa 	Actual Winner :: DCa
# KKR  **vs**  RCB 	    Predicted Winner :: RaR 	Actual Winner :: RCB
# MuI  **vs**  SRH 	    Predicted Winner :: MuI 	Actual Winner :: SRH
# RaR  **vs**  CSK 	    Predicted Winner :: CSK 	Actual Winner :: RaR
# KKR  **vs**  DCa 	    Predicted Winner :: RaR 	Actual Winner :: KKR
# PKi  **vs**  SRH 	    Predicted Winner :: RaR 	Actual Winner :: PKi
# RCB  **vs**  MuI 	    Predicted Winner :: RaR 	Actual Winner :: MuI
# DCa  **vs**  RaR 	    Predicted Winner :: RCB 	Actual Winner :: DCa
# KKR  **vs**  CSK 	    Predicted Winner :: RaR 	Actual Winner :: KKR
# RCB  **vs**  SRH 	    Predicted Winner :: MuI 	Actual Winner :: SRH
# MuI  **vs**  PKi 	    Predicted Winner :: RaR 	Actual Winner :: MuI
# KKR  **vs**  RaR 	    Predicted Winner :: DCa 	Actual Winner :: KKR
# RCB  **vs**  DCa 	    Predicted Winner :: RaR 	Actual Winner :: DCa
# PKi  **vs**  CSK 	    Predicted Winner :: RaR 	Actual Winner :: CSK
# SRH  **vs**  RaR 	    Predicted Winner :: RaR 	Actual Winner :: RaR
# MuI  **vs**  KKR 	    Predicted Winner :: RaR 	Actual Winner :: MuI
# CSK  **vs**  DCa 	    Predicted Winner :: DCa 	Actual Winner :: DCa
# PKi  **vs**  RCB 	    Predicted Winner :: RaR 	Actual Winner :: PKi
# MuI  **vs**  RaR 	    Predicted Winner :: RaR 	Actual Winner :: MuI
# KKR  **vs**  SRH 	    Predicted Winner :: RaR 	Actual Winner :: KKR
# PKi  **vs**  CSK 	    Predicted Winner :: DCa 	Actual Winner :: CSK
# RaR  **vs**  RCB 	    Predicted Winner :: RaR 	Actual Winner :: RCB
# DCa  **vs**  KKR 	    Predicted Winner :: DCa 	Actual Winner :: DCa
# SRH  **vs**  CSK 	    Predicted Winner :: PKi 	Actual Winner :: SRH
# MuI  **vs**  PKi 	    Predicted Winner :: DCa 	Actual Winner :: PKi
# RaR  **vs**  SRH 	    Predicted Winner :: SRH 	Actual Winner :: SRH
# DCa  **vs**  RCB 	    Predicted Winner :: DCa 	Actual Winner :: DCa
# KKR  **vs**  PKi 	    Predicted Winner :: MuI 	Actual Winner :: PKi
# CSK  **vs**  MuI 	    Predicted Winner :: GuL 	Actual Winner :: MuI
# RaR  **vs**  RCB 	    Predicted Winner :: PKi 	Actual Winner :: RCB
# KKR  **vs**  PKi 	    Predicted Winner :: RaR 	Actual Winner :: KKR
# SRH  **vs**  DCa 	    Predicted Winner :: PKi 	Actual Winner :: SRH
# RCB  **vs**  CSK 	    Predicted Winner :: PKi 	Actual Winner :: RCB
# KKR  **vs**  MuI 	    Predicted Winner :: RaR 	Actual Winner :: MuI
# PKi  **vs**  RaR 	    Predicted Winner :: MuI 	Actual Winner :: RaR
# CSK  **vs**  SRH 	    Predicted Winner :: DCa 	Actual Winner :: CSK
# DCa  **vs**  MuI 	    Predicted Winner :: CSK 	Actual Winner :: MuI
# KKR  **vs**  RaR 	    Predicted Winner :: DCa 	Actual Winner :: KKR
# RCB  **vs**  PKi 	    Predicted Winner :: MuI 	Actual Winner :: PKi
# SRH  **vs**  DCa 	    Predicted Winner :: RaR 	Actual Winner :: SRH
# CSK  **vs**  RaR 	    Predicted Winner :: CSK 	Actual Winner :: RaR
# RCB  **vs**  SRH 	    Predicted Winner :: RaR 	Actual Winner :: RCB
# DCa  **vs**  MuI 	    Predicted Winner :: DCa 	Actual Winner :: MuI
# KKR  **vs**  CSK 	    Predicted Winner :: CSK 	Actual Winner :: CSK
# PKi  **vs**  RaR 	    Predicted Winner :: RaR 	Actual Winner :: RaR
# MuI  **vs**  SRH 	    Predicted Winner :: MuI 	Actual Winner :: MuI
# DCa  **vs**  CSK 	    Predicted Winner :: CSK 	Actual Winner :: DCa
# RCB  **vs**  KKR 	    Predicted Winner :: MuI 	Actual Winner :: RCB
# MuI  **vs**  RaR 	    Predicted Winner :: RaR 	Actual Winner :: RaR
# SRH  **vs**  PKi 	    Predicted Winner :: KKR 	Actual Winner :: SRH
# DCa  **vs**  RaR 	    Predicted Winner :: DCa 	Actual Winner :: DCa
# RCB  **vs**  CSK 	    Predicted Winner :: PKi 	Actual Winner :: CSK
# SRH  **vs**  KKR 	    Predicted Winner :: RaR 	Actual Winner :: KKR
# DCa  **vs**  PKi 	    Predicted Winner :: DCa 	Actual Winner :: PKi
# RCB  **vs**  MuI 	    Predicted Winner :: KKR 	Actual Winner :: RCB
# MuI  **vs**  DCa 	    Predicted Winner :: DCa 	Actual Winner :: MuI
# RCB  **vs**  SRH 	    Predicted Winner :: RaR 	Actual Winner :: SRH
# DCa  **vs**  SRH 	    Predicted Winner :: DCa 	Actual Winner :: DCa
# DCa  **vs**  MuI 	    Predicted Winner :: DCa 	Actual Winner :: MuI
# Predicted  42.5 Percent Results Correctly
# Using KNN for K =  9  & Features = 6
